# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

output_file('test.html')

p =figure(title='test_flower')
p.xaxis.axis_label= 'petal_length'
p.yaxis.axis_label= 'petal_width'
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="a49e3500-c52b-4b83-9165-b8945d871720" data-root-id="1512"></div>

# %%
output_file('test.html')

p =figure(title='line_graph')
p.xaxis.axis_label= 'x-axis'
p.yaxis.axis_label= 'y-axis'
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="d2badfee-ebcc-49aa-8d19-b4064fe28c1c" data-root-id="1772"></div>

# %%
x = [2,3,4,5,6]
y = [3,4,5,6,7]
output_file('line.html')
p = figure(title = 'line_plot')
p.scatter(x,y, fill_color = 'red', legend_label = 'red points',size = 20)
show(p)
# Out:
#   <div class="bk-root" id="c7cb0c68-2593-4b3f-a844-5c94b1d8992e" data-root-id="2994"></div>
